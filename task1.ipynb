# %%
hh
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9ecdcaba8dbe> in <cell line: 1>()
# ----> 1 hh
#
# NameError: name 'hh' is not defined
